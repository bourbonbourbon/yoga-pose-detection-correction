# %%
import mediapipe as mp
import pandas as pd
import numpy as np
import cv2
import os

# %%
mp_pose = mp.solutions.pose

# %%
landmarks_points = {
    "nose": 0,
    "left_shoulder": 11, "right_shoulder": 12,
    "left_elbow": 13, "right_elbow": 14,
    "left_wrist": 15, "right_wrist": 16,
    "left_hip": 23, "right_hip": 24,
    "left_knee": 25, "right_knee": 26,
    "left_ankle": 27, "right_ankle": 28,
    "left_heel": 29, "right_heel": 30,
    "left_foot_index": 31, "right_foot_index": 32,
}

col_names = []
for i in range(len(landmarks_points.keys())):
    name = list(landmarks_points.keys())[i]
    col_names.append(name + "_x")
    col_names.append(name + "_y")
    col_names.append(name + "_z")
    col_names.append(name + "_v")

pose_name = col_names.copy()
# step_name = col_names.copy()

pose_name.append("pose")  # from 0 to n
# col_names.append("correct") # correct: 0, wrong: 1
# step_name.append("step")  # from 0 to n

# %%
pose_list = []

main_dir = "./poses_dataset/Images"
pose_dir_list = os.listdir(main_dir)

for i in range(0, len(pose_dir_list)):
    images_dir_list = os.listdir(f"{main_dir}/{pose_dir_list[i]}")
    for l in range(0, len(images_dir_list)):
        pre_list = []
        with mp_pose.Pose(static_image_mode=True, enable_segmentation=True) as pose:
            image = cv2.imread(
                f"{main_dir}/{pose_dir_list[i]}/{images_dir_list[l]}")
            result = pose.process(
                cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

            try:
                predict = True
                for landmarks in result.pose_landmarks.landmark:
                    pre_list.append(landmarks)
            except AttributeError:
                print(
                    f"No points {main_dir}/{pose_dir_list[i]}/{images_dir_list[l]}")
                predict = False

        if predict == True:
            gen1116 = np.array([
                [
                    pre_list[m].x,
                    pre_list[m].y,
                    pre_list[m].z,
                    pre_list[m].visibility
                ] for m in range(11, 17)
            ]).flatten().tolist()

            gen2333 = np.array([
                [
                    pre_list[m].x,
                    pre_list[m].y,
                    pre_list[m].z,
                    pre_list[m].visibility
                ] for m in range(23, 33)
            ]).flatten().tolist()

            gen1116.extend(gen2333)

            all_list = [
                pre_list[0].x,
                pre_list[0].y,
                pre_list[0].z,
                pre_list[0].visibility,
            ]

            all_list.extend(gen1116)
            tpl = all_list.copy()
            tpl.append(i)
            pose_list.append(tpl)

data_pose = pd.DataFrame(pose_list, columns=pose_name)
data_pose.to_csv("./csv_files/11_poses_data_pose.csv", index=False)
# Out:
# No points ./poses_dataset/Images/Ardha Chandrasana/File28.png
# No points ./poses_dataset/Images/Ardha Chandrasana/File43.png
# No points ./poses_dataset/Images/Ardha Chandrasana/File6.png
# No points ./poses_dataset/Images/Downdog/00000239.jpg
# No points ./poses_dataset/Images/Downdog/00000300.jpg
# No points ./poses_dataset/Images/Downdog/00000426.jpg
# No points ./poses_dataset/Images/Goddess/00000228.jpg
# No points ./poses_dataset/Images/Goddess/00000242.jpg
# No points ./poses_dataset/Images/Goddess/00000348.jpg
# No points ./poses_dataset/Images/Marjaryasana/File56.png
# No points ./poses_dataset/Images/Padmasana/File1.png
# No points ./poses_dataset/Images/Padmasana/File13.png
# No points ./poses_dataset/Images/Padmasana/File14.png
# No points ./poses_dataset/Images/Padmasana/File38.png
# No points ./poses_dataset/Images/Padmasana/File4.png
# No points ./poses_dataset/Images/Padmasana/File49.png
# No points ./poses_dataset/Images/Padmasana/File6.png
# No points ./poses_dataset/Images/Padmasana/File62.png
# No points ./poses_dataset/Images/Padmasana/File7.png
# No points ./poses_dataset/Images/Plank/00000249.jpg
# No points ./poses_dataset/Images/Plank/00000378.jpg
# No points ./poses_dataset/Images/Urdhva Mukha Svsnssana/File20.png
# No points ./poses_dataset/Images/Urdhva Mukha Svsnssana/File38.png
# No points ./poses_dataset/Images/Urdhva Mukha Svsnssana/File55.png
# No points ./poses_dataset/Images/Utkatasana/File1.png
# No points ./poses_dataset/Images/Utkatasana/File11.png
# No points ./poses_dataset/Images/Utkatasana/File22.png
# No points ./poses_dataset/Images/Utkatasana/File27.png
# No points ./poses_dataset/Images/Utkatasana/File3.png
# No points ./poses_dataset/Images/Utkatasana/File31.png
# No points ./poses_dataset/Images/Utkatasana/File32.png
# No points ./poses_dataset/Images/Utkatasana/File41.png
# No points ./poses_dataset/Images/Utkatasana/File49.png
# No points ./poses_dataset/Images/Utkatasana/File57.png
# No points ./poses_dataset/Images/Utkatasana/File81.png
# No points ./poses_dataset/Images/Warrior2/00000137.jpg
